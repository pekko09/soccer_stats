# %%
from moduls.fixtures import MatchFixtures

bvb = MatchFixtures(teamshort='Dortmund', year_season=2025)

for c in {'bl1', 'ucl', 'dfb', 'uel'}:
    bvb.get_matches(comp=c)
# Out:
# HTTP-Fehler: 404 Client Error: Not Found for url: https://api.openligadb.de/getmatchdta/dfb/2025
# 0 new matches found for team Borussia Dortmund in campaign DFB
# HTTP-Fehler: 404 Client Error: Not Found for url: https://api.openligadb.de/getmatchdta/ucl/2025
# 0 new matches found for team Borussia Dortmund in campaign CL
# HTTP-Fehler: 404 Client Error: Not Found for url: https://api.openligadb.de/getmatchdta/bl1/2025
# 0 new matches found for team Borussia Dortmund in campaign BL
# HTTP-Fehler: 404 Client Error: Not Found for url: https://api.openligadb.de/getmatchdta/uel/2025
# 0 new matches found for team Borussia Dortmund in campaign EL

# %%
print(bvb.teamid)
# Out:
# None

# %%
comp_labels = {'bl1': 'BL', 'ucl': 'CL', 'dfb': 'DFB'}

for match in bvb.matches:
    comp = match['leagueShortcut']
    home = match['team1']['teamName']
    away = match['team2']['teamName']
    date = match['matchDateTime']

    print(f"{date} {comp_labels[comp]} {home} - {away}")
# Out:
# 2025-08-18T20:45:00 DFB Rot-Weiss Essen - Borussia Dortmund
# 2025-08-23T18:30:00 BL FC St. Pauli - Borussia Dortmund
# 2025-08-31T17:30:00 BL Borussia Dortmund - 1. FC Union Berlin
# 2025-09-13T15:30:00 BL 1. FC Heidenheim 1846 - Borussia Dortmund
# 2025-09-16T21:00:00 CL Juventus Turin - Borussia Dortmund
# 2025-09-21T19:30:00 BL Borussia Dortmund - VfL Wolfsburg
# 2025-09-27T15:30:00 BL 1. FSV Mainz 05 - Borussia Dortmund
# 2025-10-01T21:00:00 CL Borussia Dortmund - Athletic Club
# 2025-10-04T15:30:00 BL Borussia Dortmund - RB Leipzig
# 2025-10-18T18:30:00 BL FC Bayern München - Borussia Dortmund
# 2025-10-21T21:00:00 CL FC Kopenhagen - Borussia Dortmund
# 2025-10-25T18:30:00 BL Borussia Dortmund - 1. FC Köln
# 2025-10-28T18:30:00 DFB Eintracht Frankfurt - Borussia Dortmund
# 2025-10-31T20:30:00 BL FC Augsburg - Borussia Dortmund
# 2025-11-05T21:00:00 CL Manchester City - Borussia Dortmund
# 2025-11-08T15:30:00 BL Hamburger SV - Borussia Dortmund
# 2025-11-22T15:30:00 BL Borussia Dortmund - VfB Stuttgart
# 2025-11-25T21:00:00 CL Borussia Dortmund - FC Villareal
# 2025-11-29T18:30:00 BL Bayer 04 Leverkusen - Borussia Dortmund
# 2025-12-06T15:30:00 BL Borussia Dortmund - TSG Hoffenheim
# 2025-12-10T21:00:00 CL Borussia Dortmund - FK Bodö/Glimt
# 2025-12-13T15:30:00 BL SC Freiburg - Borussia Dortmund
# 2025-12-20T15:30:00 BL Borussia Dortmund - Borussia Mönchengladbach
# 2026-01-10T15:30:00 BL Eintracht Frankfurt - Borussia Dortmund
# 2026-01-13T20:30:00 BL Borussia Dortmund - SV Werder Bremen
# 2026-01-17T15:30:00 BL Borussia Dortmund - FC St. Pauli
# 2026-01-20T21:00:00 CL Tottenham Hotspur - Borussia Dortmund
# 2026-01-24T15:30:00 BL 1. FC Union Berlin - Borussia Dortmund
# 2026-01-28T21:00:00 CL Borussia Dortmund - Inter Mailand
# 2026-01-31T15:30:00 BL Borussia Dortmund - 1. FC Heidenheim 1846
# 2026-02-07T15:30:00 BL VfL Wolfsburg - Borussia Dortmund
# 2026-02-14T15:30:00 BL Borussia Dortmund - 1. FSV Mainz 05
# 2026-02-21T15:30:00 BL RB Leipzig - Borussia Dortmund
# 2026-02-28T15:30:00 BL Borussia Dortmund - FC Bayern München
# 2026-03-07T15:30:00 BL 1. FC Köln - Borussia Dortmund
# 2026-03-14T15:30:00 BL Borussia Dortmund - FC Augsburg
# 2026-03-21T15:30:00 BL Borussia Dortmund - Hamburger SV
# 2026-04-04T15:30:00 BL VfB Stuttgart - Borussia Dortmund
# 2026-04-11T15:30:00 BL Borussia Dortmund - Bayer 04 Leverkusen
# 2026-04-18T15:30:00 BL TSG Hoffenheim - Borussia Dortmund
# 2026-04-25T15:30:00 BL Borussia Dortmund - SC Freiburg
# 2026-05-02T15:30:00 BL Borussia Mönchengladbach - Borussia Dortmund
# 2026-05-09T15:30:00 BL Borussia Dortmund - Eintracht Frankfurt
# 2026-05-16T15:30:00 BL SV Werder Bremen - Borussia Dortmund

# %%
bvb.matches[1]['matchResults']
# Out:
# [{'resultID': 118530,
#   'resultName': 'Halbzeit',
#   'pointsTeam1': 0,
#   'pointsTeam2': 1,
#   'resultOrderID': 1,
#   'resultTypeID': 1,
#   'resultDescription': 'Ergebnis nach Ende der ersten Halbzeit'},
#  {'resultID': 118531,
#   'resultName': 'Endergebnis',
#   'pointsTeam1': 3,
#   'pointsTeam2': 3,
#   'resultOrderID': 2,
#   'resultTypeID': 2,
#   'resultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'}]

# %%
import requests as rq

comp = 'bl1'
year_season = 2025

apimain = 'https://api.openligadb.de'
apiep_teams = f"/getavailableteams/{comp}/{year_season}"
apiurl = f"{apimain}{apiep_teams}"

resp = rq.get(url=apiurl)
if resp.status_code == 200:
    teams = resp.json()

# %%
print(len(teams[1]))
print(teams[1])
for t in teams:
    print(t['shortName'])

if teams
# Out:
# 5
# {'teamId': 65, 'teamName': '1. FC Köln', 'shortName': 'Köln', 'teamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/1._FC_Koeln_Logo_2014–.svg/296px-1._FC_Koeln_Logo_2014–.svg.png', 'teamGroupName': None}
# Heidenheim
# Köln
# Union Berlin
# Mainz
# Leverkusen
# Dortmund
# Gladbach
# Frankfurt
# Augsburg
# Bayern
# St. Pauli
# HSV
# Leipzig
# Freiburg
# Bremen
# Hoffenheim
# Stuttgart
# Wolfsburg
